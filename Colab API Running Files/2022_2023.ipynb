# %% [markdown]
# # Run the API on the 2022_2023 School Student Addresses
# ## Goal
# Translate the Student Addresses into valid queries that can be given to an API and exchanged with coordinates for plot-able data points.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd

# Get the file and set to a variable named filename
filename = os.path.join(os.getcwd(), "/content/drive/MyDrive/CS506_Project/API/Altered_datasets", "cleaned_student_addresses_2022_2023.csv")

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(filename, header = 0)

# %%
def clean_zipcode(zip_code):
    if pd.isna(zip_code):
        return zip_code # Handle NaN values
    s_zip = str(zip_code).strip()

    # If the zip code contains a hyphen, take only the first part
    if '-' in s_zip:
        s_zip = s_zip.split('-')[0]

    # Handle cases like "002134" which should become "02134"
    if len(s_zip) == 6 and s_zip.startswith('00'):
        return s_zip[1:]

    return s_zip

# Apply the cleaning function to the '6e. zip' column
df['6e. zip'] = df['6e. zip'].apply(clean_zipcode)

# %%
df.head(50)
# Out:
#    6a. street # 6b. street name 6c. street suffix 6e. zip  \
# 0          1235             Vfw           Parkway   02132
# 1             7        Aberdeen            Street   02215
# 2            17        Aberdeen            Street   02215
# 3           144         Addison            Street   02128
# 4           601          Albany            Street   02118
# 5            12       Albemarle             Court   02115
# 6            20          Alcott            Street   02134
# 7            15           Aldie            Street   02134
# 8            23           Aldie            Street   02134
# 9            37           Aldie            Street   02134
# 10          192       Alleghany            Street   02120
# 11           35         Allston            Street   02134
# 12           48         Allston            Street   02134
# 13           48         Allston            Street   02134
# 14           53         Allston            Street   02134
# 15           73         Allston            Street   02134
# 16           75         Allston            Street   02134
# 17           84         Allston            Street   02134
# 18          108         Allston            Street   02134
# 19          128         Allston            Street   02134
# 20          168         Allston            Street   02134
# 21          184         Allston            Street   02134
# 22          192         Allston            Street   02134
# 23          317         Allston            Street   02135
# 24          319         Allston            Street   02135
# 25           60        Anderson            Street   02114
# 26          115        Appleton            Street   02116
# 27           19           Arden            Street   02134
# 28           25         Ashford            Street   02134
# 29           41         Ashford            Street   02134
# 30           46         Ashford            Street   02134
# 31            7         Ashford           Terrace   02134
# 32           21           Athol            Street   02134
# 33           93          Austin            Street   02136
# 34            2           Avery            Street   02111
# 35           12       Bay State              Road   02215
# 36           25       Bay State              Road   02215
# 37           29       Bay State              Road   02215
# 38           43       Bay State              Road   02215
# 39           45       Bay State              Road   02215
# 40           47       Bay State              Road   02215
# 41          215          Beacon            Street   02116
# 42          219          Beacon            Street   02116
# 43          231          Beacon            Street   02116
# 44          233          Beacon            Street   02116
# 45          236          Beacon            Street   02116
# 46          237          Beacon            Street   02116
# 47          239          Beacon            Street   02116
# 48          247          Beacon            Street   02116
# 49          250          Beacon            Street   02116
#
#    7. undergraduate (u) or graduate (g) 8. full-time (ft) or part-time (pt)  \
# 0                                     U                                  FT
# 1                                     U                                  FT
# 2                                     U                                  FT
# 3                                     U                                  FT
# 4                                     U                                  FT
# 5                                     U                                  FT
# 6                                     U                                  FT
# 7                                     U                                  FT
# 8                                     G                                  PT
# 9                                     U                                  FT
# 10                                    U                                  FT
# 11                                    U                                  FT
# 12                                    U                                  FT
# 13                                    U                                  FT
# 14                                    U                                  FT
# 15                                    U                                  FT
# 16                                    U                                  FT
# 17                                    U                                  FT
# 47  2022-2023      239 Beacon St  Boston  Massachusetts
# 48  2022-2023      247 Beacon St  Boston  Massachusetts
# 49  2022-2023      250 Beacon St  Boston  Massachusetts

# %% [markdown]
# ## Formatting for the API Query functions needed
# Use of Copilot to create the corresponding code to help translate the columns that we have into usable strings that can be compiled into a valid url to query the api.

# %%
import time
import requests
import pandas as pd
import numpy as np
from typing import Optional, Tuple, Dict

GEOCODE_URL = "https://geocode.maps.co/search"

def _build_address_string(street: Optional[str], city: Optional[str],
                          state: Optional[str], postalcode: Optional[str]) -> str:
    parts = []
    if street and str(street).strip():
        parts.append(str(street).strip())
    if city and str(city).strip():
        parts.append(str(city).strip())
    if state and str(state).strip():
        parts.append(str(state).strip())
    if postalcode and str(postalcode).strip():
        parts.append(str(postalcode).strip())
    return ", ".join(parts)

def geocode_single(session: requests.Session,
                    street: Optional[str],
                    city: Optional[str],
                    state: Optional[str],
                    postalcode: Optional[str],
                    api_key: Optional[str] = None,
                    country: Optional[str] = "US",
                    timeout: float = 10.0,
                    max_retries: int = 4,
                    pause: float = 1.0) -> Tuple[Optional[float], Optional[float]]:
    """
    Geocode a single address. Returns (lat, lon) or (None, None) if no result.
    Uses exponential backoff for 429/503 responses.
    """
    address_str = _build_address_string(street, city, state, postalcode)
    if not address_str:
        return None, None

    params = {
        "format": "json",
        "limit": 1
    }
    # Prefer structured search: include components when available
    if street:
        params["street"] = street
    if city:
        params["city"] = city
    if state:
        params["state"] = state
    if postalcode:
        params["postalcode"] = postalcode
    if country:
        params["country"] = country

    # If user prefers to pass api_key as query param, uncomment next line
    # if api_key: params["api_key"] = api_key

    headers = {
        "User-Agent": "geocode-client/1.0"
    }
    if api_key:
        headers["Authorization"] = f"Bearer {api_key}"

    backoff = pause
    for attempt in range(1, max_retries + 1):
        try:
            resp = session.get(GEOCODE_URL, params=params, headers=headers, timeout=timeout)
        except requests.RequestException:
            # network failure
            if attempt == max_retries:
                return None, None
            time.sleep(backoff)
            backoff *= 2
            continue

        if resp.status_code == 200:
            try:
                data = resp.json()
            except ValueError:
                return None, None
            if isinstance(data, list) and len(data) > 0:
                first = data[0]
                try:
                    lat = float(first.get("lat"))
                    lon = float(first.get("lon"))
                    return lat, lon
                except Exception:
                    return None, None
            else:
                # no matches
                return None, None

        if resp.status_code in (429, 503):
            # rate limited or service unavailable - backoff and retry
            if attempt == max_retries:
                return None, None
            time.sleep(backoff)
            backoff *= 2
            continue

        # for 403/4xx/5xx other than 429/503 -> don't retry too aggressively
        # if 403, you might be blocked/need to contact API provider
        return None, None

    return None, None


def geocode_addresses(df: pd.DataFrame,
                      street_col: str,
                      city_col: Optional[str],
                      state_col: Optional[str],
                      postal_col: Optional[str],
                      api_key: Optional[str] = None,
                      country: str = "US",
                      timeout: float = 10.0,
                      pause: float = 1.0,
                      max_retries: int = 4,
                      max_rows: Optional[int] = None,
                      show_progress: bool = True) -> pd.DataFrame:
    """
    Geocode addresses from a DataFrame and return a copy with 'latitude_geocoded'
    and 'longitude_geocoded' columns appended.

    Example:
      df2 = geocode_addresses(df, "street_col", "city_col", "state_col", "zip_col", api_key="XXX")
      # then df2 has new columns you can assign back: df["lat"] = df2["latitude_geocoded"]
    """
    session = requests.Session()
    cache: Dict[str, Tuple[Optional[float], Optional[float]]] = {}

    n = len(df) if max_rows is None else min(len(df), max_rows)
    latitudes = []
    longitudes = []

    it = range(n)
    for i in it:
        if show_progress and (i % 50 == 0):
            print(f"Geocoding row {i+1}/{n} ...")
        row = df.iloc[i]
        street = row.get(street_col, None)
        city = row.get(city_col, None) if city_col else None
        state = row.get(state_col, None) if state_col else None
        postal = row.get(postal_col, None) if postal_col else None

        addr_key = _build_address_string(street, city, state, postal)
        if addr_key in cache:
            lat, lon = cache[addr_key]
        else:
            lat, lon = geocode_single(session,
                                      street=street,
                                      city=city,
                                      state=state,
                                      postalcode=postal,
                                      api_key=api_key,
                                      country=country,
                                      timeout=timeout,
                                      max_retries=max_retries,
                                      pause=pause)
            cache[addr_key] = (lat, lon)
            # polite pause between requests to avoid being rate-limited
            time.sleep(pause)

        latitudes.append(lat if lat is not None else np.nan)
        longitudes.append(lon if lon is not None else np.nan)

    # Build output DataFrame (copy to avoid mutating input)
    out = df.copy()
    # New columns are aligned with the subset length; if max_rows set, fill rest with NaN
    if max_rows is not None and max_rows < len(df):
        # create full-length lists
        lat_full = [np.nan] * len(df)
        lon_full = [np.nan] * len(df)
        for j in range(max_rows):
            lat_full[j] = latitudes[j]
            lon_full[j] = longitudes[j]
        out["latitude_geocoded"] = lat_full
        out["longitude_geocoded"] = lon_full
    else:
        out["latitude_geocoded"] = latitudes + [np.nan] * (len(df) - len(latitudes))
        out["longitude_geocoded"] = longitudes + [np.nan] * (len(df) - len(longitudes))

    return out

# %%
df_test = geocode_addresses(df, "Street_combined", "City", "State", "6e. zip", "INSERTKEY")

display(df_test)
# Out:
# Geocoding row 1/11058 ...
# Geocoding row 51/11058 ...
# Geocoding row 101/11058 ...
# Geocoding row 151/11058 ...
# Geocoding row 201/11058 ...
# Geocoding row 251/11058 ...
# Geocoding row 301/11058 ...
# Geocoding row 351/11058 ...
# Geocoding row 401/11058 ...
# Geocoding row 451/11058 ...
# Geocoding row 501/11058 ...
# Geocoding row 551/11058 ...
# Geocoding row 601/11058 ...
# Geocoding row 651/11058 ...
# Geocoding row 701/11058 ...
# Geocoding row 751/11058 ...
# Geocoding row 801/11058 ...
# Geocoding row 851/11058 ...
# Geocoding row 901/11058 ...
# Geocoding row 951/11058 ...
# Geocoding row 1001/11058 ...
# Geocoding row 1051/11058 ...
# Geocoding row 1101/11058 ...
# Geocoding row 1151/11058 ...
# Geocoding row 1201/11058 ...
# Geocoding row 1251/11058 ...
# Geocoding row 1301/11058 ...
# Geocoding row 1351/11058 ...
# Geocoding row 1401/11058 ...
# Geocoding row 1451/11058 ...
# Geocoding row 1501/11058 ...
# Geocoding row 1551/11058 ...
# Geocoding row 1601/11058 ...
# Geocoding row 1651/11058 ...
# Geocoding row 1701/11058 ...
# Geocoding row 1751/11058 ...
# Geocoding row 1801/11058 ...
# Geocoding row 1851/11058 ...
# Geocoding row 1901/11058 ...
# Geocoding row 1951/11058 ...
# Geocoding row 2001/11058 ...
# Geocoding row 2051/11058 ...
# Geocoding row 2101/11058 ...
# Geocoding row 2151/11058 ...
# Geocoding row 2201/11058 ...
# Geocoding row 2251/11058 ...
# Geocoding row 2301/11058 ...
# Geocoding row 2351/11058 ...
# Geocoding row 2401/11058 ...
# Geocoding row 2451/11058 ...
# Geocoding row 2501/11058 ...
# Geocoding row 2551/11058 ...
# Geocoding row 2601/11058 ...
# Geocoding row 2651/11058 ...
# Geocoding row 2701/11058 ...
# Geocoding row 2751/11058 ...
# Geocoding row 2801/11058 ...
# Geocoding row 2851/11058 ...
# Geocoding row 2901/11058 ...
# Geocoding row 2951/11058 ...
# Geocoding row 3001/11058 ...
# Geocoding row 3051/11058 ...
# Geocoding row 3101/11058 ...
# Geocoding row 3151/11058 ...
# Geocoding row 3201/11058 ...
# Geocoding row 3251/11058 ...
# Geocoding row 3301/11058 ...
# Geocoding row 3351/11058 ...
# Geocoding row 3401/11058 ...
# Geocoding row 3451/11058 ...
# Geocoding row 3501/11058 ...
# Geocoding row 3551/11058 ...
# Geocoding row 3601/11058 ...
# Geocoding row 3651/11058 ...
# Geocoding row 3701/11058 ...
# Geocoding row 3751/11058 ...
# Geocoding row 3801/11058 ...
# Geocoding row 3851/11058 ...
# Geocoding row 3901/11058 ...
# Geocoding row 3951/11058 ...
# Geocoding row 4001/11058 ...
# Geocoding row 4051/11058 ...
# Geocoding row 4101/11058 ...
# Geocoding row 4151/11058 ...
# Geocoding row 4201/11058 ...
# Geocoding row 4251/11058 ...
# Geocoding row 4301/11058 ...
# Geocoding row 4351/11058 ...
# Geocoding row 4401/11058 ...
# Geocoding row 4451/11058 ...
# Geocoding row 4501/11058 ...
# Geocoding row 4551/11058 ...
# Geocoding row 4601/11058 ...
# Geocoding row 4651/11058 ...
# Geocoding row 4701/11058 ...
# Geocoding row 4751/11058 ...
# Geocoding row 4801/11058 ...
# Geocoding row 4851/11058 ...
# Geocoding row 4901/11058 ...
# Geocoding row 4951/11058 ...
# Geocoding row 5001/11058 ...
# Geocoding row 5051/11058 ...
# Geocoding row 5101/11058 ...
# Geocoding row 5151/11058 ...
# Geocoding row 5201/11058 ...
# Geocoding row 5251/11058 ...
# Geocoding row 5301/11058 ...
# Geocoding row 5351/11058 ...
# Geocoding row 5401/11058 ...
# Geocoding row 5451/11058 ...
# Geocoding row 5501/11058 ...
# Geocoding row 5551/11058 ...
# Geocoding row 5601/11058 ...
# Geocoding row 5651/11058 ...
# Geocoding row 5701/11058 ...
# Geocoding row 5751/11058 ...
# Geocoding row 5801/11058 ...
# Geocoding row 5851/11058 ...
# Geocoding row 5901/11058 ...
# Geocoding row 5951/11058 ...
# Geocoding row 6001/11058 ...
# Geocoding row 6051/11058 ...
# Geocoding row 6101/11058 ...
# Geocoding row 6151/11058 ...
# Geocoding row 6201/11058 ...
# Geocoding row 6251/11058 ...
# Geocoding row 6301/11058 ...
# Geocoding row 6351/11058 ...
# Geocoding row 6401/11058 ...
# Geocoding row 6451/11058 ...
# Geocoding row 6501/11058 ...
# Geocoding row 6551/11058 ...
# Geocoding row 6601/11058 ...
# Geocoding row 6651/11058 ...
# Geocoding row 6701/11058 ...
# Geocoding row 6751/11058 ...
# Geocoding row 6801/11058 ...
# Geocoding row 6851/11058 ...
# Geocoding row 6901/11058 ...
# Geocoding row 6951/11058 ...
# Geocoding row 7001/11058 ...
# Geocoding row 7051/11058 ...
# Geocoding row 7101/11058 ...
# Geocoding row 7151/11058 ...
# Geocoding row 7201/11058 ...
# Geocoding row 7251/11058 ...
# Geocoding row 7301/11058 ...
# Geocoding row 7351/11058 ...
# Geocoding row 7401/11058 ...
# Geocoding row 7451/11058 ...
# Geocoding row 7501/11058 ...
# Geocoding row 7551/11058 ...
# Geocoding row 7601/11058 ...
# Geocoding row 7651/11058 ...
# Geocoding row 7701/11058 ...
# Geocoding row 7751/11058 ...
# Geocoding row 7801/11058 ...
# Geocoding row 7851/11058 ...
# Geocoding row 7901/11058 ...
# Geocoding row 7951/11058 ...
# Geocoding row 8001/11058 ...
# Geocoding row 8051/11058 ...
# Geocoding row 8101/11058 ...
# Geocoding row 8151/11058 ...
# Geocoding row 8201/11058 ...
# Geocoding row 8251/11058 ...
# Geocoding row 8301/11058 ...
# Geocoding row 8351/11058 ...
# Geocoding row 8401/11058 ...
# Geocoding row 8451/11058 ...
# Geocoding row 8501/11058 ...
# Geocoding row 8551/11058 ...
# Geocoding row 8601/11058 ...
# Geocoding row 8651/11058 ...
# Geocoding row 8701/11058 ...
# Geocoding row 8751/11058 ...
# Geocoding row 8801/11058 ...
# Geocoding row 8851/11058 ...
# Geocoding row 8901/11058 ...
# Geocoding row 8951/11058 ...
# Geocoding row 9001/11058 ...
# Geocoding row 9051/11058 ...
# Geocoding row 9101/11058 ...
# Geocoding row 9151/11058 ...
# Geocoding row 9201/11058 ...
# Geocoding row 9251/11058 ...
# Geocoding row 9301/11058 ...
# Geocoding row 9351/11058 ...
# Geocoding row 9401/11058 ...
# Geocoding row 9451/11058 ...
# Geocoding row 9501/11058 ...
# Geocoding row 9551/11058 ...
# Geocoding row 9601/11058 ...
# Geocoding row 9651/11058 ...
# Geocoding row 9701/11058 ...
# Geocoding row 9751/11058 ...
# Geocoding row 9801/11058 ...
# Geocoding row 9851/11058 ...
# Geocoding row 9901/11058 ...
# Geocoding row 9951/11058 ...
# Geocoding row 10001/11058 ...
# Geocoding row 10051/11058 ...
# Geocoding row 10101/11058 ...
# Geocoding row 10151/11058 ...
# Geocoding row 10201/11058 ...
# Geocoding row 10251/11058 ...
# Geocoding row 10301/11058 ...
# Geocoding row 10351/11058 ...
# Geocoding row 10401/11058 ...
# Geocoding row 10451/11058 ...
# Geocoding row 10501/11058 ...
# Geocoding row 10551/11058 ...
# Geocoding row 10601/11058 ...
# Geocoding row 10651/11058 ...
# Geocoding row 10701/11058 ...
# Geocoding row 10751/11058 ...
# Geocoding row 10801/11058 ...
# Geocoding row 10851/11058 ...
# Geocoding row 10901/11058 ...
# Geocoding row 10951/11058 ...
# Geocoding row 11001/11058 ...
# Geocoding row 11051/11058 ...
#       6a. street #  6b. street name 6c. street suffix 6e. zip  \
# 0             1235              Vfw           Parkway   02132
# 1                7         Aberdeen            Street   02215
# 2               17         Aberdeen            Street   02215
# 3              144          Addison            Street   02128
# 4              601           Albany            Street   02118
# ...            ...              ...               ...     ...
# 11053           28  Senator Bolling            Circle   02124
# 11054           27         Tafthill           Terrace   02131
# 11055          944              Vfw           Parkway   02132
# 11056          736     West Roxbury           Parkway   02131
# 11057            8  Whittier Apt 6K             Place   02114
#
#       7. undergraduate (u) or graduate (g)  \
# 0                                        U
# 1                                        U
# 2                                        U
# 3                                        U
# 4                                        U
# ...                                    ...
# 11053                                    G
# 11054                                    G
# 11055                                    G
# 11056                                    G
# 11057                                    G
#
#       8. full-time (ft) or part-time (pt) 9. at-home or not-at-home  \
# 0                                      FT                   At Home
# 1                                      FT                       NaN
# 2                                      FT                       NaN
# 3                                      FT                       NaN
# 4                                      FT                       NaN
# ...                                   ...                       ...
# 11053                           Full Time                      Home
# 11054                           Full Time                      Home
# 11055                           Full Time                      Home
# 11056                           Part Time                      Home
# 11057                           Full Time                      Home
#
#                                          university       year  \
# 0                                 Bay State College  2022-2023
# 1      Berklee College of Music-Boston Conservatory  2022-2023
# 2      Berklee College of Music-Boston Conservatory  2022-2023
# 3      Berklee College of Music-Boston Conservatory  2022-2023
# 4      Berklee College of Music-Boston Conservatory  2022-2023
# ...                                             ...        ...
# 11053                                Boston College  2022-2023
# 11054                                Boston College  2022-2023
# 11055                                Boston College  2022-2023
# 11056                                Boston College  2022-2023
# 11057                                Boston College  2022-2023
#
#                  Street_combined    City          State  latitude_geocoded  \
# 0               1235 Vfw Parkway  Boston  Massachusetts          42.278976
# 1                  7 Aberdeen St  Boston  Massachusetts          42.346305
# 2                 17 Aberdeen St  Boston  Massachusetts          42.346156
# 3                 144 Addison St  Boston  Massachusetts          42.385526
# 4                  601 Albany St  Boston  Massachusetts          42.337167
# ...                          ...     ...            ...                ...
# 11053  28 Senator Bolling Circle  Boston  Massachusetts          42.290909
# 11054        27 Tafthill Terrace  Boston  Massachusetts          42.287884
# 11055                        NaN  Boston  Massachusetts          42.354992
# 11056                        NaN  Boston  Massachusetts          42.354992
# 11057   8 Whittier  Apt 6K Place  Boston  Massachusetts                NaN
#
#        longitude_geocoded
# 0              -71.171238
# 1              -71.103884
# 2              -71.103808
# 3              -71.014492
# 4              -71.068785
# ...                   ...
# 11053          -71.092921
# 11054          -71.127589
# 11055          -71.134306
# 11056          -71.134306
# 11057                 NaN
#
# [11058 rows x 14 columns]

# %%
# Count NaN values in each column
nan_counts = df_test.isnull().sum()

print("NaN counts per column:")
print(nan_counts)
# Out:
# NaN counts per column:
# 6a. street #                             115
# 6b. street name                            0
# 6c. street suffix                          0
# 6e. zip                                    7
# 7. undergraduate (u) or graduate (g)       0
# 8. full-time (ft) or part-time (pt)        0
# 9. at-home or not-at-home               3177
# university                                 0
# year                                       0
# Street_combined                          383
# City                                       0
# State                                      0
# latitude_geocoded                       1445
# longitude_geocoded                      1445
# dtype: int64

# %%
# Define the path where you want to save the CSV file
# Use forward slashes or raw string to avoid escape character issues
output_path = r"/content/drive/MyDrive/CS506_Project/API/Results"

# Create the directory if it doesn't exist
os.makedirs(output_path, exist_ok=True)

# Save each DataFrame to a separate CSV file with a descriptive name
df_test.to_csv(os.path.join(output_path, "api_results_student_addresses_2022_2023.csv"), index=False)

print("Files saved successfully to:")
print(output_path)
# Out:
# Files saved successfully to:
# /content/drive/MyDrive/CS506_Project/API/Results

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd

# Get the file and set to a variable named filename
filename = os.path.join(os.getcwd(), "/content/drive/MyDrive/CS506_Project/API/Altered_datasets", "cleaned_student_addresses_2020_2021.csv")

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(filename, header = 0)

# %%
df.head(50)
# Out:
#    6a. street # 6b. street name 6c. street suffix 6e. zip  \
# 0           101           Canal            Street   02114
# 1           175         Blossom            Street   02114
# 2            45          Stuart            Street   02115
# 3           797      Huntington            Avenue   02115
# 4             3         Shabazz               Way   02119
# 5            39        Bartlett            Street   02119
# 6            62          Forest            Street   02119
# 7           306          Dudley            Street   02119
# 8             1       Mcgreevey               Way   02120
# 9            10         Hammond            Street   02120
# 10          143          Fisher            Avenue   02120
# 11           21      Castlegate              Road   02121
# 12           37         Gleason            Street   02121
# 13           76        Lawrence            Avenue   02121
# 14           20        Montello            Street   02122
# 15           66     Beach Point             Place   02124
# 16          200         Faneuil            Street   02124
# 17           50         Medford            Street   02124
# 18            8         Mallard            Avenue   02124
# 19           38         Lindsey            Street   02124
# 20          507      Washington            Street   02124
# 21          284          Talbot            Avenue   02124
# 22           25          Kelton            Street   02126
# 23          166         Orlando            Street   02126
# 24          330         Tremont            Street   02126
# 25            5           Leeds            Street   02127
# 26            3         Chaucer            Street   02128
# 27            6           Eutaw            Street   02128
# 28            9          Cunard               Way   02128
# 29           21          Lamson            Street   02128
# 30           52         Faywood            Avenue   02128
# 31          102        Saratoga            Street   02128
# 32           10         Fifield            Street   02130
# 33           28        Bardwell            Street   02130
# 34           35         Woodman            Street   02130
# 35          203          Harold            Street   02130
# 36          229          Centre            Street   02130
# 37           11         Nonquit            Street   02131
# 38           56         Seymour            Street   02131
# 39           71         Clement            Avenue   02132
# 40           18         Bodwell            Street   02134
# 41            6            Fern            Street   02134
# 42          158          Kelton            Street   02134
# 43           60       Woodstock            Avenue   02135
# 44            7          Tacoma            Street   02136
# 45           21        Yarmouth            Street   02136
# 46           39          Pierce            Street   02136
# 47           92      Wesminster            Street   02136
# 48          190      Georgetown             Place   02136
# 49          680     Georgetowne             Drive   02136
#
#    7. undergraduate (u) or graduate (g) 8. full-time (ft) or part-time (pt)  \
# 0                                     U                                  FT
# 1                                     U                                  FT
# 2                                     U                                  FT
# 3                                     U                                  PT
# 4                                     U                                  PT
# 5                                     U                                  FT
# 6                                     U                                  PT
# 7                                     U                                  PT
# 8                                     U                                  FT
# 9                                     U                                  PT
# 10                                    U                                  FT
# 11                                    U                                  FT
# 12                                    U                                  FT
# 13                                    U                                  FT
# 14                                    U                                  PT
# 15                                    U                                  FT
# 16                                    U                                  FT
# 17                                    U                                  PT
# 18                                    U                                  PT
# 19                                    U                                  PT
# 20                                    U                                  FT
# 21                                    U                                  FT
# 22                                    U                                  FT
# 23                                    U                                  FT
# 24                                    U                                  FT
# 25                                    U                                  FT
# 26                                    U                                  FT
# 27                                    U                                  FT
# 28                                    U                                  PT
# 29                                    U                                  FT
# 30                                    U                                  FT
# 31                                    U                                  FT
# 32                                    U                                  FT
# 33                                    U                                  FT
# 34                                    U                                  FT
# 35                                    U                                  FT
# 36                                    U                                  FT
# 37                                    U                                  FT
# 38                                    U                                  FT
# 39                                    U                                  PT
# 40                                    U                                  FT
# 41                                    U                                  FT
# 42                                    U                                  FT
# 43                                    U                                  FT
# 44                                    U                                  PT
# 45                                    U                                  FT
# 46                                    U                                  FT
# 47                                    U                                  FT
# 48                                    U                                  FT
# 49                                    U                                  PT
#
#    9. at-home or not-at-home         university       year  \
# 0                          N  Bay State College  2020-2021
# 1                          N  Bay State College  2020-2021
# 2                          N  Bay State College  2020-2021
# 3                          N  Bay State College  2020-2021
# 4                          N  Bay State College  2020-2021
# 5                          N  Bay State College  2020-2021
# 6                          N  Bay State College  2020-2021
# 7                          N  Bay State College  2020-2021
# 8                          N  Bay State College  2020-2021
# 9                          N  Bay State College  2020-2021
# 10                         N  Bay State College  2020-2021
# 11                         N  Bay State College  2020-2021
# 12                         N  Bay State College  2020-2021
# 13                         N  Bay State College  2020-2021
# 14                         N  Bay State College  2020-2021
# 15                         N  Bay State College  2020-2021
# 16                         N  Bay State College  2020-2021
# 17                         N  Bay State College  2020-2021
# 18                         N  Bay State College  2020-2021
# 19                         N  Bay State College  2020-2021
# 20                         N  Bay State College  2020-2021
# 21                         N  Bay State College  2020-2021
# 22                         N  Bay State College  2020-2021
# 23                         N  Bay State College  2020-2021
# 24                         N  Bay State College  2020-2021
# 25                         N  Bay State College  2020-2021
# 26                         N  Bay State College  2020-2021
# 27                         N  Bay State College  2020-2021
# 28                         N  Bay State College  2020-2021
# 29                         N  Bay State College  2020-2021
# 30                         N  Bay State College  2020-2021
# 31                         N  Bay State College  2020-2021
# 32                         N  Bay State College  2020-2021
# 33                         N  Bay State College  2020-2021
# 34                         N  Bay State College  2020-2021
# 35                         N  Bay State College  2020-2021
# 36                         N  Bay State College  2020-2021
# 37                         N  Bay State College  2020-2021
# 38                         N  Bay State College  2020-2021
# 39                         N  Bay State College  2020-2021
# 40                         N  Bay State College  2020-2021
# 41                         N  Bay State College  2020-2021
# 42                         N  Bay State College  2020-2021
# 43                         N  Bay State College  2020-2021
# 44                         N  Bay State College  2020-2021
# 45                         N  Bay State College  2020-2021
# 46                         N  Bay State College  2020-2021
# 47                         N  Bay State College  2020-2021
# 48                         N  Bay State College  2020-2021
# 49                         N  Bay State College  2020-2021
#
#          Street_combined    City          State
# 0           101 Canal St  Boston  Massachusetts
# 1         175 Blossom St  Boston  Massachusetts
# 2           45 Stuart St  Boston  Massachusetts
# 3     797 Huntington Ave  Boston  Massachusetts
# 4          3 Shabazz Way  Boston  Massachusetts
# 5         39 Bartlett St  Boston  Massachusetts
# 6           62 Forest St  Boston  Massachusetts
# 7          306 Dudley St  Boston  Massachusetts
# 8        1 Mcgreevey Way  Boston  Massachusetts
# 9          10 Hammond St  Boston  Massachusetts
# 10        143 Fisher Ave  Boston  Massachusetts
# 11      21 Castlegate Rd  Boston  Massachusetts
# 12         37 Gleason St  Boston  Massachusetts
# 13       76 Lawrence Ave  Boston  Massachusetts
# 14        20 Montello St  Boston  Massachusetts
# 15  66 Beach Point Place  Boston  Massachusetts
# 16        200 Faneuil St  Boston  Massachusetts
# 17         50 Medford St  Boston  Massachusetts
# 18         8 Mallard Ave  Boston  Massachusetts
# 19         38 Lindsey St  Boston  Massachusetts
# 20     507 Washington St  Boston  Massachusetts
# 21        284 Talbot Ave  Boston  Massachusetts
# 22          25 Kelton St  Boston  Massachusetts
# 23        166 Orlando St  Boston  Massachusetts
# 24        330 Tremont St  Boston  Massachusetts
# 25            5 Leeds St  Boston  Massachusetts
# 26          3 Chaucer St  Boston  Massachusetts
# 27            6 Eutaw St  Boston  Massachusetts
# 28          9 Cunard Way  Boston  Massachusetts
# 29          21 Lamson St  Boston  Massachusetts
# 30        52 Faywood Ave  Boston  Massachusetts
# 31       102 Saratoga St  Boston  Massachusetts
# 32         10 Fifield St  Boston  Massachusetts
# 33        28 Bardwell St  Boston  Massachusetts
# 34         35 Woodman St  Boston  Massachusetts
# 35         203 Harold St  Boston  Massachusetts
# 36         229 Centre St  Boston  Massachusetts
# 37         11 Nonquit St  Boston  Massachusetts
# 38         56 Seymour St  Boston  Massachusetts
# 39        71 Clement Ave  Boston  Massachusetts
# 40         18 Bodwell St  Boston  Massachusetts
# 41             6 Fern St  Boston  Massachusetts
# 42         158 Kelton St  Boston  Massachusetts
# 43      60 Woodstock Ave  Boston  Massachusetts
# 44           7 Tacoma St  Boston  Massachusetts
# 45        21 Yarmouth St  Boston  Massachusetts
# 46          39 Pierce St  Boston  Massachusetts
# 47      92 Wesminster St  Boston  Massachusetts
# 48  190 Georgetown Place  Boston  Massachusetts
# 49   680 Georgetowne Dr.  Boston  Massachusetts

# %%
def clean_zipcode(zip_code):
    if pd.isna(zip_code):
        return zip_code # Handle NaN values
    s_zip = str(zip_code).strip()

    # If the zip code contains a hyphen, take only the first part
    if '-' in s_zip:
        s_zip = s_zip.split('-')[0]

    # Handle cases like "002134" which should become "02134"
    if len(s_zip) == 6 and s_zip.startswith('00'):
        return s_zip[1:]

    return s_zip

# Apply the cleaning function to the '6e. zip' column
df['6e. zip'] = df['6e. zip'].apply(clean_zipcode)

# %%
import time
import requests
import pandas as pd
import numpy as np
from typing import Optional, Tuple, Dict

GEOCODE_URL = "https://geocode.maps.co/search"

def _build_address_string(street: Optional[str], city: Optional[str],
                          state: Optional[str], postalcode: Optional[str]) -> str:
    parts = []
    if street and str(street).strip():
        parts.append(str(street).strip())
    if city and str(city).strip():
        parts.append(str(city).strip())
    if state and str(state).strip():
        parts.append(str(state).strip())
    if postalcode and str(postalcode).strip():
        parts.append(str(postalcode).strip())
    return ", ".join(parts)

def geocode_single(session: requests.Session,
                    street: Optional[str],
                    city: Optional[str],
                    state: Optional[str],
                    postalcode: Optional[str],
                    api_key: Optional[str] = None,
                    country: Optional[str] = "US",
                    timeout: float = 10.0,
                    max_retries: int = 4,
                    pause: float = 1.0) -> Tuple[Optional[float], Optional[float]]:
    """
    Geocode a single address. Returns (lat, lon) or (None, None) if no result.
    Uses exponential backoff for 429/503 responses.
    """
    address_str = _build_address_string(street, city, state, postalcode)
    if not address_str:
        return None, None

    params = {
        "format": "json",
        "limit": 1
    }
    # Prefer structured search: include components when available
    if street:
        params["street"] = street
    if city:
        params["city"] = city
    if state:
        params["state"] = state
    if postalcode:
        params["postalcode"] = postalcode
    if country:
        params["country"] = country

    # If user prefers to pass api_key as query param, uncomment next line
    # if api_key: params["api_key"] = api_key

    headers = {
        "User-Agent": "geocode-client/1.0"
    }
    if api_key:
        headers["Authorization"] = f"Bearer {api_key}"

    backoff = pause
    for attempt in range(1, max_retries + 1):
        try:
            resp = session.get(GEOCODE_URL, params=params, headers=headers, timeout=timeout)
        except requests.RequestException:
            # network failure
            if attempt == max_retries:
                return None, None
            time.sleep(backoff)
            backoff *= 2
            continue

        if resp.status_code == 200:
            try:
                data = resp.json()
            except ValueError:
                return None, None
            if isinstance(data, list) and len(data) > 0:
                first = data[0]
                try:
                    lat = float(first.get("lat"))
                    lon = float(first.get("lon"))
                    return lat, lon
                except Exception:
                    return None, None
            else:
                # no matches
                return None, None

        if resp.status_code in (429, 503):
            # rate limited or service unavailable - backoff and retry
            if attempt == max_retries:
                return None, None
            time.sleep(backoff)
            backoff *= 2
            continue

        # for 403/4xx/5xx other than 429/503 -> don't retry too aggressively
        # if 403, you might be blocked/need to contact API provider
        return None, None

    return None, None


def geocode_addresses(df: pd.DataFrame,
                      street_col: str,
                      city_col: Optional[str],
                      state_col: Optional[str],
                      postal_col: Optional[str],
                      api_key: Optional[str] = None,
                      country: str = "US",
                      timeout: float = 10.0,
                      pause: float = 1.0,
                      max_retries: int = 4,
                      max_rows: Optional[int] = None,
                      show_progress: bool = True) -> pd.DataFrame:
    """
    Geocode addresses from a DataFrame and return a copy with 'latitude_geocoded'
    and 'longitude_geocoded' columns appended.

    Example:
      df2 = geocode_addresses(df, "street_col", "city_col", "state_col", "zip_col", api_key="XXX")
      # then df2 has new columns you can assign back: df["lat"] = df2["latitude_geocoded"]
    """
    session = requests.Session()
    cache: Dict[str, Tuple[Optional[float], Optional[float]]] = {}

    n = len(df) if max_rows is None else min(len(df), max_rows)
    latitudes = []
    longitudes = []

    it = range(n)
    for i in it:
        if show_progress and (i % 50 == 0):
            print(f"Geocoding row {i+1}/{n} ...")
        row = df.iloc[i]
        street = row.get(street_col, None)
        city = row.get(city_col, None) if city_col else None
        state = row.get(state_col, None) if state_col else None
        postal = row.get(postal_col, None) if postal_col else None

        addr_key = _build_address_string(street, city, state, postal)
        if addr_key in cache:
            lat, lon = cache[addr_key]
        else:
            lat, lon = geocode_single(session,
                                      street=street,
                                      city=city,
                                      state=state,
                                      postalcode=postal,
                                      api_key=api_key,
                                      country=country,
                                      timeout=timeout,
                                      max_retries=max_retries,
                                      pause=pause)
            cache[addr_key] = (lat, lon)
            # polite pause between requests to avoid being rate-limited
            time.sleep(pause)

        latitudes.append(lat if lat is not None else np.nan)
        longitudes.append(lon if lon is not None else np.nan)

    # Build output DataFrame (copy to avoid mutating input)
    out = df.copy()
    # New columns are aligned with the subset length; if max_rows set, fill rest with NaN
    if max_rows is not None and max_rows < len(df):
        # create full-length lists
        lat_full = [np.nan] * len(df)
        lon_full = [np.nan] * len(df)
        for j in range(max_rows):
            lat_full[j] = latitudes[j]
            lon_full[j] = longitudes[j]
        out["latitude_geocoded"] = lat_full
        out["longitude_geocoded"] = lon_full
    else:
        out["latitude_geocoded"] = latitudes + [np.nan] * (len(df) - len(latitudes))
        out["longitude_geocoded"] = longitudes + [np.nan] * (len(df) - len(longitudes))

    return out

# %%
# An example of how to run the above function, but loading the lat and long columns
# for each dataset will be handled outside this notebook as each one will take 3- 4hrs
#provide your API key below

df_test = geocode_addresses(df, "Street_combined", "City", "State", "6e. zip", "68eda5007d6f0812943358onga6ed4e")
# Out:
# Geocoding row 1/10718 ...
# Geocoding row 51/10718 ...
# Geocoding row 101/10718 ...
# Geocoding row 151/10718 ...
# Geocoding row 201/10718 ...
# Geocoding row 251/10718 ...
# Geocoding row 301/10718 ...
# Geocoding row 351/10718 ...
# Geocoding row 401/10718 ...
# Geocoding row 451/10718 ...
# Geocoding row 501/10718 ...
# Geocoding row 551/10718 ...
# Geocoding row 601/10718 ...
# Geocoding row 651/10718 ...
# Geocoding row 701/10718 ...
# Geocoding row 751/10718 ...
# Geocoding row 801/10718 ...
# Geocoding row 851/10718 ...
# Geocoding row 901/10718 ...
# Geocoding row 951/10718 ...
# Geocoding row 1001/10718 ...
# Geocoding row 1051/10718 ...
# Geocoding row 1101/10718 ...
# Geocoding row 1151/10718 ...
# Geocoding row 1201/10718 ...
# Geocoding row 1251/10718 ...
# Geocoding row 1301/10718 ...
# Geocoding row 1351/10718 ...
# Geocoding row 1401/10718 ...
# Geocoding row 1451/10718 ...
# Geocoding row 1501/10718 ...
# Geocoding row 1551/10718 ...
# Geocoding row 1601/10718 ...
# Geocoding row 1651/10718 ...
# Geocoding row 1701/10718 ...
# Geocoding row 1751/10718 ...
# Geocoding row 1801/10718 ...
# Geocoding row 1851/10718 ...
# Geocoding row 1901/10718 ...
# Geocoding row 1951/10718 ...
# Geocoding row 2001/10718 ...
# Geocoding row 2051/10718 ...
# Geocoding row 2101/10718 ...
# Geocoding row 2151/10718 ...
# Geocoding row 2201/10718 ...
# Geocoding row 2251/10718 ...
# Geocoding row 2301/10718 ...
# Geocoding row 2351/10718 ...
# Geocoding row 2401/10718 ...
# Geocoding row 2451/10718 ...
# Geocoding row 2501/10718 ...
# Geocoding row 2551/10718 ...
# Geocoding row 2601/10718 ...
# Geocoding row 2651/10718 ...
# Geocoding row 2701/10718 ...
# Geocoding row 2751/10718 ...
# Geocoding row 2801/10718 ...
# Geocoding row 2851/10718 ...
# Geocoding row 2901/10718 ...
# Geocoding row 2951/10718 ...
# Geocoding row 3001/10718 ...
# Geocoding row 3051/10718 ...
# Geocoding row 3101/10718 ...
# Geocoding row 3151/10718 ...
# Geocoding row 3201/10718 ...
# Geocoding row 3251/10718 ...
# Geocoding row 3301/10718 ...
# Geocoding row 3351/10718 ...
# Geocoding row 3401/10718 ...
# Geocoding row 3451/10718 ...
# Geocoding row 3501/10718 ...
# Geocoding row 3551/10718 ...
# Geocoding row 3601/10718 ...
# Geocoding row 3651/10718 ...
# Geocoding row 3701/10718 ...
# Geocoding row 3751/10718 ...
# Geocoding row 3801/10718 ...
# Geocoding row 3851/10718 ...
# Geocoding row 3901/10718 ...
# Geocoding row 3951/10718 ...
# Geocoding row 4001/10718 ...
# Geocoding row 4051/10718 ...
# Geocoding row 4101/10718 ...
# Geocoding row 4151/10718 ...
# Geocoding row 4201/10718 ...
# Geocoding row 4251/10718 ...
# Geocoding row 4301/10718 ...
# Geocoding row 4351/10718 ...
# Geocoding row 4401/10718 ...
# Geocoding row 4451/10718 ...
# Geocoding row 4501/10718 ...
# Geocoding row 4551/10718 ...
# Geocoding row 4601/10718 ...
# Geocoding row 4651/10718 ...
# Geocoding row 4701/10718 ...
# Geocoding row 4751/10718 ...
# Geocoding row 4801/10718 ...
# Geocoding row 4851/10718 ...
# Geocoding row 4901/10718 ...
# Geocoding row 4951/10718 ...
# Geocoding row 5001/10718 ...
# Geocoding row 5051/10718 ...
# Geocoding row 5101/10718 ...
# Geocoding row 5151/10718 ...
# Geocoding row 5201/10718 ...
# Geocoding row 5251/10718 ...
# Geocoding row 5301/10718 ...
# Geocoding row 5351/10718 ...
# Geocoding row 5401/10718 ...
# Geocoding row 5451/10718 ...
# Geocoding row 5501/10718 ...
# Geocoding row 5551/10718 ...
# Geocoding row 5601/10718 ...
# Geocoding row 5651/10718 ...
# Geocoding row 5701/10718 ...
# Geocoding row 5751/10718 ...
# Geocoding row 5801/10718 ...
# Geocoding row 5851/10718 ...
# Geocoding row 5901/10718 ...
# Geocoding row 5951/10718 ...
# Geocoding row 6001/10718 ...
# Geocoding row 6051/10718 ...
# Geocoding row 6101/10718 ...
# Geocoding row 6151/10718 ...
# Geocoding row 6201/10718 ...
# Geocoding row 6251/10718 ...
# Geocoding row 6301/10718 ...
# Geocoding row 6351/10718 ...
# Geocoding row 6401/10718 ...
# Geocoding row 6451/10718 ...
# Geocoding row 6501/10718 ...
# Geocoding row 6551/10718 ...
# Geocoding row 6601/10718 ...
# Geocoding row 6651/10718 ...
# Geocoding row 6701/10718 ...
# Geocoding row 6751/10718 ...
# Geocoding row 6801/10718 ...
# Geocoding row 6851/10718 ...
# Geocoding row 6901/10718 ...
# Geocoding row 6951/10718 ...
# Geocoding row 7001/10718 ...
# Geocoding row 7051/10718 ...
# Geocoding row 7101/10718 ...
# Geocoding row 7151/10718 ...
# Geocoding row 7201/10718 ...
# Geocoding row 7251/10718 ...
# Geocoding row 7301/10718 ...
# Geocoding row 7351/10718 ...
# Geocoding row 7401/10718 ...
# Geocoding row 7451/10718 ...
# Geocoding row 7501/10718 ...
# Geocoding row 7551/10718 ...
# Geocoding row 7601/10718 ...
# Geocoding row 7651/10718 ...
# Geocoding row 7701/10718 ...
# Geocoding row 7751/10718 ...
# Geocoding row 7801/10718 ...
# Geocoding row 7851/10718 ...
# Geocoding row 7901/10718 ...
# Geocoding row 7951/10718 ...
# Geocoding row 8001/10718 ...
# Geocoding row 8051/10718 ...
# Geocoding row 8101/10718 ...
# Geocoding row 8151/10718 ...
# Geocoding row 8201/10718 ...
# Geocoding row 8251/10718 ...
# Geocoding row 8301/10718 ...
# Geocoding row 8351/10718 ...
# Geocoding row 8401/10718 ...
# Geocoding row 8451/10718 ...
# Geocoding row 8501/10718 ...
# Geocoding row 8551/10718 ...
# Geocoding row 8601/10718 ...
# Geocoding row 8651/10718 ...
# Geocoding row 8701/10718 ...
# Geocoding row 8751/10718 ...
# Geocoding row 8801/10718 ...
# Geocoding row 8851/10718 ...
# Geocoding row 8901/10718 ...
# Geocoding row 8951/10718 ...
# Geocoding row 9001/10718 ...
# Geocoding row 9051/10718 ...
# Geocoding row 9101/10718 ...
# Geocoding row 9151/10718 ...
# Geocoding row 9201/10718 ...
# Geocoding row 9251/10718 ...
# Geocoding row 9301/10718 ...
# Geocoding row 9351/10718 ...
# Geocoding row 9401/10718 ...
# Geocoding row 9451/10718 ...
# Geocoding row 9501/10718 ...
# Geocoding row 9551/10718 ...
# Geocoding row 9601/10718 ...
# Geocoding row 9651/10718 ...
# Geocoding row 9701/10718 ...
# Geocoding row 9751/10718 ...
# Geocoding row 9801/10718 ...
# Geocoding row 9851/10718 ...
# Geocoding row 9901/10718 ...
# Geocoding row 9951/10718 ...
# Geocoding row 10001/10718 ...
# Geocoding row 10051/10718 ...
# Geocoding row 10101/10718 ...
# Geocoding row 10151/10718 ...
# Geocoding row 10201/10718 ...
# Geocoding row 10251/10718 ...
# Geocoding row 10301/10718 ...
# Geocoding row 10351/10718 ...
# Geocoding row 10401/10718 ...
# Geocoding row 10451/10718 ...
# Geocoding row 10501/10718 ...
# Geocoding row 10551/10718 ...
# Geocoding row 10601/10718 ...
# Geocoding row 10651/10718 ...
# Geocoding row 10701/10718 ...

# %%
# Define the path where you want to save the CSV file
# Use forward slashes or raw string to avoid escape character issues
output_path = r"/content/drive/MyDrive/CS506_Project/API/Results"

# Create the directory if it doesn't exist
os.makedirs(output_path, exist_ok=True)

# Save each DataFrame to a separate CSV file with a descriptive name
df_test.to_csv(os.path.join(output_path, "api_results_student_addresses_2020_2021.csv"), index=False)

print("Files saved successfully to:")
print(output_path)
# Out:
# Files saved successfully to:
# /content/drive/MyDrive/CS506_Project/API/Results
